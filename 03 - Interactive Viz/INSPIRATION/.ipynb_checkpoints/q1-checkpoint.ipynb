# %%
import os
import pandas as pd
import json
import folium
import numpy as np

# %% [markdown]
# ## `Question 1`

# %%
europe_geo_path = r'topojson/europe.topojson.json'
geo_json_data = json.load(open(europe_geo_path))

# %%
map_europe = folium.Map([56,15], tiles='Mapbox Bright', zoom_start=3)
map_europe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.TopoJson(open(europe_geo_path), 'objects.europe', name='topojson').add_to(map_europe)
map_europe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rates = pd.read_csv('data/europe.csv')
rates.head()
# Out:
#                    geo\time  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0         EU (28 countries)  18.7  17.4  15.5  15.6  19.9    21  21.7  23.2
# 1         EU (27 countries)  18.6  17.3  15.5  15.6  19.9    21  21.6  23.1
# 2  Euro area (19 countries)  17.9  16.6    15  15.5    20  20.9  21.2  23.4
# 3  Euro area (18 countries)  17.9  16.6    15  15.5  19.9  20.8  21.1  23.4
# 4                   Belgium  21.5  20.5  18.8    18  21.9  22.4  18.7  19.8
#
#    2013  2014  2015  2016
# 0  23.6  22.2  20.3  18.7
# 1  23.5    22  20.2  18.6
# 2  24.2  23.8  22.4  20.9
# 3  24.2  23.8  22.4    21
# 4  23.7  23.2  22.1  20.1

# %%
rates = rates[['geo\\time', '2016']][4:40]
rates = rates.rename(columns={'geo\\time': 'Country', '2016': 'Unemployment Rate'})
rates.index = np.arange(1, len(rates) + 1)
rates.head()
# Out:
#           Country Unemployment Rate
# 1         Belgium              20.1
# 2        Bulgaria              17.2
# 3  Czech Republic              10.5
# 4         Denmark                12
# 5         Germany               7.1

# %%
# Data from tradingeconomics.com
rates['Unemployment Rate'][30] = 2.3 #Liechtenstein
rates['Unemployment Rate'][33] = 20.58 #Montenegro
rates['Unemployment Rate'][35] = 16.1 #Albania
rates['Unemployment Rate'][36] = 15.91 #Serbia

# %%
rates['Unemployment Rate'] = list(map(lambda x: float(x), rates['Unemployment Rate']))
rates.head()
# Out:
#           Country  Unemployment Rate
# 1         Belgium               20.1
# 2        Bulgaria               17.2
# 3  Czech Republic               10.5
# 4         Denmark               12.0
# 5         Germany                7.1

# %%
map_europe = folium.Map([50,15], tiles='Mapbox Bright', zoom_start=4)
map_europe.choropleth(geo_data=geo_json_data, data=rates,
             columns=['Country', 'Unemployment Rate'],
             key_on='properties.NAME',
             topojson= 'objects.europe',
             fill_color='BuPu', fill_opacity=0.8, line_opacity=0.9,
             #threshold_scale = np.linspace(rates['Unemployment rate'].min(), rates['Unemployment rate'].max(), 12, dtype=float),
             legend_name='Percentage of unemployment (%)')
map_europe
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
